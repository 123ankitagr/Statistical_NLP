# %% [markdown]
# To run on colab:
#
# https://colab.research.google.com/drive/1rK1YvuJ6pe3_uH0B1-0QLYYSjCwnt4n8#scrollTo=ZwH9Z4lDuWNw

# %%
import nltk
nltk.download('senseval')
# Out:
# [nltk_data] Downloading package senseval to /root/nltk_data...
# [nltk_data]   Unzipping corpora/senseval.zip.
# True

# %%
# !python ex9_material_em_starter.py
# Out:
# Streaming output truncated to the last 5000 lines.
# 0.6507648297150121
# 0.029320071930126167
# 0.03806690845685065
# 0.9326130196130232
# 0.017652058446843377
# 0.698871780572291
# 0.28347616098086553
# 0.06774111633835635
# 0.33658657806800385
# 0.5956723055936398
# 0.0001529976025830275
# 0.0020060636908910607
# 0.997840938706526
# 0.16763210109343182
# 0.7465407600908871
# 0.085827138815681
# 0.014358962173157543
# 0.5062514550804887
# 0.4793895827463537
# 0.027706536217154368
# 0.001019831776036442
# 0.9712736320068093
# 0.10502502809037668
# 0.23292052321829299
# 0.6620544486913303
# 0.006577266783647373
# 0.024431165326732562
# 0.96899156788962
# 0.04884917840048137
# 0.0668725491058304
# 0.8842782724936883
# 0.0010038811069428455
# 0.000199826239322527
# 0.9987962926537346
# 0.006788042668778227
# 0.0017331894320491783
# 0.9914787678991726
# 0.06429725840624632
# 0.16185993778926644
# 0.7738428038044872
# 0.11606911083950565
# 0.8503909816142792
# 0.033539907546215206
# ...
